# %%
import pandas as pd

# %%
df1= pd.read_parquet("/Users/ritikahiremath/Downloads/Data/OK_Measurements/2024.02.14_22.00.10_Grinding/raw/Sampling100KHz_Irms_Grinding-Grinding spindle current L1-Grinding spindle current L2-Grinding spindle current L3-0.parquet")

# %%
df1
# Out:
#          Irms_Grinding_rate100000_clipping0_batch0  \
# 0                                         0.103928
# 1                                         0.109450
# 2                                         0.109388
# 3                                         0.111707
# 4                                         0.113854
# ...                                            ...
# 2280573                                   0.027839
# 2280574                                   0.023175
# 2280575                                   0.019097
# 2280576                                   0.023368
# 2280577                                   0.015131
#
#          Grinding spindle current L1_rate100000_clipping0_batch0  \
# 0                                                -0.115736
# 1                                                -0.129770
# 2                                                -0.109039
# 3                                                -0.116374
# ...

# %%
df2= pd.read_parquet("/Users/ritikahiremath/Downloads/Data/OK_Measurements/2024.02.14_22.00.10_Grinding/raw/Sampling2000KHz_AEKi-0.parquet")

# %%
df2
# Out:
#           AEKi_rate2000000_clipping0_batch0
# 0                                 -0.000679
# 1                                  0.003445
# 2                                 -0.000679
# 3                                 -0.002053
# 4                                 -0.000679
# ...                                     ...
# 45613115                          -0.000679
# 45613116                           0.002070
# 45613117                           0.007568
# 45613118                           0.000696
# 45613119                          -0.010300
#
# [45613120 rows x 1 columns]
